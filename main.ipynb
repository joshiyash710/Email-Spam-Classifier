# %%
# !pip install numpy pandas scikit-learn nltk matplotlib seaborn wordcloud jupyter tqdm
# Out:
# Requirement already satisfied: numpy in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (2.2.6)
# Requirement already satisfied: pandas in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (2.3.3)
# Requirement already satisfied: scikit-learn in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (1.7.2)
# Requirement already satisfied: nltk in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (3.9.2)
# Requirement already satisfied: matplotlib in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (3.10.8)
# Requirement already satisfied: seaborn in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (0.13.2)
# Requirement already satisfied: wordcloud in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (1.9.5)
# Requirement already satisfied: jupyter in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (1.1.1)
# Requirement already satisfied: tqdm in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: click in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from nltk) (2025.11.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: notebook in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyter) (7.5.1)
# Requirement already satisfied: jupyter-console in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyter) (7.16.6)
# Requirement already satisfied: ipykernel in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyter) (7.1.0)
# Requirement already satisfied: ipywidgets in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyter) (8.1.8)
# Requirement already satisfied: jupyterlab in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyter) (4.5.1)
# Requirement already satisfied: colorama in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from ipykernel->jupyter) (1.8.19)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from ipykernel->jupyter) (8.37.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from ipykernel->jupyter) (8.7.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from ipykernel->jupyter) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from ipykernel->jupyter) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from ipykernel->jupyter) (7.2.1)
# Requirement already satisfied: pyzmq>=25 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from ipykernel->jupyter) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from ipykernel->jupyter) (6.5.4)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from ipykernel->jupyter) (5.14.3)
# Requirement already satisfied: decorator in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.2.1)
# Requirement already satisfied: exceptiongroup in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (1.3.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (4.15.0)
# Requirement already satisfied: wcwidth in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.5)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.5.1)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from ipywidgets->jupyter) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from ipywidgets->jupyter) (3.0.16)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyterlab->jupyter) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyterlab->jupyter) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyterlab->jupyter) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyterlab->jupyter) (57.4.0)
# Requirement already satisfied: tomli>=1.2.2 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: anyio in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (4.12.0)
# Requirement already satisfied: certifi in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (1.0.9)
# Requirement already satisfied: idna in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.23.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.9.0)
# Requirement already satisfied: babel>=2.10 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.13.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (4.25.1)
# Requirement already satisfied: requests>=2.31 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.32.5)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jinja2>=3.0.3->jupyterlab->jupyter) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.30.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.3)
# Requirement already satisfied: rfc3339-validator in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from nbconvert->jupyter) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.3.0)
# Requirement already satisfied: defusedxml in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from nbconvert->jupyter) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from nbconvert->jupyter) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.21.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.6.2)
# Requirement already satisfied: lark>=1.2.2 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.23)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.8.1)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.4.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (0.2.3)

# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('spam.csv', encoding='latin-1')

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %% [markdown]
# ### 1) Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
df.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'],inplace=True)

# %%
df.sample(5)
# Out:
#        v1                                                 v2
# 3308  ham  Okie Ì_ wan meet at bishan? Cos me at bishan n...
# 492   ham                   Sorry,in meeting I'll call later
# 4386  ham                        S.i'm watching it in live..
# 576   ham  I'm tired of arguing with you about this week ...
# 1371  ham  I though we shd go out n have some fun so bar ...

# %%
df.rename(columns={'v1':'target','v2':'text'},inplace=True)
df.sample(5)
# Out:
#      target                                               text
# 2096    ham                                        I'm done...
# 1317   spam  Win the newest ÛÏHarry Potter and the Order o...
# 2266   spam  <Forwarded from 88877>FREE entry into our å£25...
# 3009    ham  Imagine Life WITHOUT ME... see.. How fast u ar...
# 4192    ham                            Ok i'm coming home now.

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df['target'] = encoder.fit_transform(df['target'])

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(403)

# %%
df = df.drop_duplicates(keep='first')

# %%
df.shape
# Out:
# (5169, 2)

# %% [markdown]
# ### 2) EDA

# %%
df['target'].value_counts()
# Out:
# target
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\joshi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df['num_characters'] = df['text'].apply(len)

# %%
df.head()
# Out:
#    target                                               text  num_characters
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61

# %%
df['num_words'] = df['text'].apply(lambda x : len(nltk.word_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words
# 0         24
# 1          8
# 2         37
# 3         13
# 4         15

# %%
df['num_sentences'] = df['text'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df[['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     5169.000000  5169.000000    5169.000000
# mean        78.977945    18.455794       1.965564
# std         58.236293    13.324758       1.448541
# min          2.000000     1.000000       1.000000
# 25%         36.000000     9.000000       1.000000
# 50%         60.000000    15.000000       1.000000
# 75%        117.000000    26.000000       2.000000
# max        910.000000   220.000000      38.000000

# %%
#non spam
df[df['target'] == 0][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     4516.000000  4516.000000    4516.000000
# mean        70.459256    17.123782       1.820195
# std         56.358207    13.493970       1.383657
# min          2.000000     1.000000       1.000000
# 25%         34.000000     8.000000       1.000000
# 50%         52.000000    13.000000       1.000000
# 75%         90.000000    22.000000       2.000000
# max        910.000000   220.000000      38.000000

# %%
#spam
df[df['target'] == 1][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters   num_words  num_sentences
# count      653.000000  653.000000     653.000000
# mean       137.891271   27.667688       2.970904
# std         30.137753    7.008418       1.488425
# min         13.000000    2.000000       1.000000
# 25%        132.000000   25.000000       2.000000
# 50%        149.000000   29.000000       3.000000
# 75%        157.000000   32.000000       4.000000
# max        224.000000   46.000000       9.000000

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['target'] == 0]['num_characters'])
sns.histplot(df[df['target'] == 1]['num_characters'],color='red')
# Out:
# <Axes: xlabel='num_characters', ylabel='Count'>

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['target'] == 0]['num_words'])
sns.histplot(df[df['target'] == 1]['num_words'],color='red')
# Out:
# <Axes: xlabel='num_words', ylabel='Count'>

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\joshi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\joshi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ### 3) Data Preprocessing

# %%
import nltk
import string

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
ps = PorterStemmer()
stop_words = set(stopwords.words('english'))

def transform_text(text):
    text = text.lower()
    text = nltk.word_tokenize(text)

    y = []
    for i in text:
        if i.isalnum():
            y.append(i)
    text = y[:]
    y.clear()

    for i in text : 
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)
    text = y[:]
    y.clear()

    for i in text :
        y.append(ps.stem(i))
    return " ".join(y)

# %%
transform_text("I'm gonna be home soon and i don't want to talk about this stuff anymore tonight, k? I've cried enough today.")
# Out:
# 'gon na home soon want talk stuff anymor tonight k cri enough today'

# %%
df['text'][10]
# Out:
# "I'm gonna be home soon and i don't want to talk about this stuff anymore tonight, k? I've cried enough today."

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
ps.stem('loving')
# Out:
# 'love'

# %%
df['transformed_text'] = df['text'].apply(transform_text)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %%
# !python -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (25.3)

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (1.9.5)
# Requirement already satisfied: numpy>=1.19 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from wordcloud) (2.2.6)
# Requirement already satisfied: pillow in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from wordcloud) (12.1.0)
# Requirement already satisfied: matplotlib in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from wordcloud) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from matplotlib->wordcloud) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from matplotlib->wordcloud) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from matplotlib->wordcloud) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\joshi\desktop\nlp_work\email_spam_classifier_project\spam-env\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)

# %%
from wordcloud import WordCloud
wc = WordCloud(width=500,height=500,min_font_size=10,background_color='white')

# %%
spam_wc = wc.generate(df[df['target'] == 1]['transformed_text'].str.cat(sep=" "))

# %%
ham_wc = wc.generate(df[df['target'] == 0]['transformed_text'].str.cat(sep=" "))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %%
spam_corpus = []
for msg in df[df['target'] == 1]['transformed_text'].tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
len(spam_corpus)
# Out:
# 9939

# %%
from collections import Counter
sns.barplot(pd.DataFrame(Counter(spam_corpus).most_common(30))[0],pd.DataFrame(Counter(spam_corpus).most_common(30))[1])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 2
#       1 from collections import Counter
# ----> 2 sns.barplot(pd.DataFrame(Counter(spam_corpus).most_common(30))[0],pd.DataFrame(Counter(spam_corpus).most_common(30))[1])
#       3 plt.xticks(rotation='vertical')
#       4 plt.show()
#
# TypeError: barplot() takes from 0 to 1 positional arguments but 2 were given
